# %%
import os

# import numpy as np

from detector_testing_system.characteristic.read_noise import show_intensity, research_read_noise, research_relative_read_noise
from detector_testing_system.data import load_data
# from detector_testing_system.device import run_device
# from detector_testing_system.experiment import ExperimentConfig, run_experiment
from detector_testing_system.output import Output

# %%
LABEL = 'C22H052'
THRESHOLD = 40

# %%
# config = ExperimentConfig.from_ini(
#     filepath=os.path.join('.', 'ini', 'C23K053.ini'),
# )

# %%
# device = run_device(
#     config=config,
# )
# run_experiment(
#     device=device,
#     config=config,
#     params=[
#         (1_000, np.full((100), 2)),
#     ],
#     label=label,
#     force=True,
# )

data = load_data(
    label=os.path.join(LABEL, 'read-noise'),
    # show=True,
)

# %%
read_noise = research_read_noise(
    data=data,
    show=True,
)

# %%
relative_read_noise = research_relative_read_noise(
    data=data,
    show=True,
)

# %%
n = 42

read_noise = show_intensity(
    data=data, n=n,
    show=True,
)
